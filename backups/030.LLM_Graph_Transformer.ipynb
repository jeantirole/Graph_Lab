# %%
# Type hints
from typing import Any, Dict, List, Tuple

# Standard library
import ast
import logging
import re
import warnings

# Third-party packages - Data manipulation
import pandas as pd
from tqdm import tqdm

# Third-party packages - Environment & Database
from dotenv import load_dotenv
from neo4j import GraphDatabase

# Third-party packages - Error handling & Retry logic
from tenacity import retry, stop_after_attempt, wait_exponential

# Langchain - Core
from langchain.chains import GraphCypherQAChain
from langchain.prompts import PromptTemplate
from langchain_core.documents import Document

# Langchain - Models & Connectors
#from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAI
#from langchain_ollama.llms import OllamaLLM

# Langchain - Graph & Experimental
from langchain_community.graphs import Neo4jGraph
from langchain_experimental.graph_transformers import LLMGraphTransformer

# Suppress warnings
warnings.filterwarnings('ignore')

# Load environment variables
load_dotenv()
# Out:
# False

# %%
movies = pd.read_csv('/home/eric/srcs/Graph_Lab/sample_data/wiki_movie_plots_deduped.csv') # adjust the path if you manually downloaded the dataset
movies.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    """Clean and preprocess DataFrame.
    
    Args:
        data: Input DataFrame
        
    Returns:
        Cleaned DataFrame
    """
    df.drop(["Wiki Page"], axis=1, inplace=True)

    # Drop duplicates
    df = df.drop_duplicates(subset='Title', keep='first')
    
    # Get object columns
    col_obj = df.select_dtypes(include=["object"]).columns
    
    # Clean string columns
    for col in col_obj:
        # Strip whitespace
        df[col] = df[col].str.strip()
        
        # Replace unknown/empty values
        df[col] = df[col].apply(
            lambda x: None if pd.isna(x) or x.lower() in ["", "unknown"] 
            else x.capitalize()
        )
    
    # Drop rows with any null values
    df = df.dropna(how="any", axis=0)
    
    return df

movies = clean_data(movies).head(1000)
movies.head()
# Out:
#     Release Year                     Title Origin/Ethnicity  \
# 13          1907              Daniel boone         American
# 15          1907              Laughing gas         American
# 16          1908  The adventures of dollie         American
# 17          1908           The black viper         American
# 18          1908    A calamitous elopement         American
#
#                                    Director  \
# 13  Wallace mccutcheon and ediwin s. porter
# 15                     Edwin stanton porter
# 16                           D. w. griffith
# 17                           D. w. griffith
# 18                            D.w. griffith
#
#                                  Cast         Genre  \
# 13  William craven, florence lawrence  Biographical
# 15    Bertha regustus, edward boulden        Comedy
# 16  Arthur v. johnson, linda arvidson         Drama
# 17                     D. w. griffith         Drama
# 18       Harry solter, linda arvidson        Comedy
#
#                                                  Plot
# 13  Boone's daughter befriends an indian maiden as...
# 15  The plot is that of a black woman going to the...
# 16  On a beautiful summer day a father and mother ...
# 17  A thug accosts a girl as she leaves her workpl...
# 18  A young couple decides to elope after being ca...

# %%
class Neo4jConnection:
    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()
        print("Connection closed")

    def reset_database(self):
        with self.driver.session() as session:
            session.run("MATCH (n) DETACH DELETE n")
            print("Database resetted successfully!")

    def execute_query(self, query, parameters=None):
        with self.driver.session() as session:
            result = session.run(query, parameters or {})
            return [record for record in result]

# %%
uri = "bolt://localhost:7687"
user = "neo4j"
password = "ilovemovies"
conn = Neo4jConnection(uri, user, password)
conn.reset_database()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_async_compat/network/_bolt_socket.py:564, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     563 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 564 s.connect(resolved_address)
#     565 s.settimeout(t)
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_async_compat/network/_bolt_socket.py:750, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     749 try:
# --> 750     s = BoltSocket._connect(
#     751         resolved_address, tcp_timeout, keep_alive
#     752     )
#     753     s = BoltSocket._secure(
#     754         s, resolved_address._host_name, ssl_context
#     755     )
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_async_compat/network/_bolt_socket.py:586, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     585 if isinstance(error, OSError):
# --> 586     raise ServiceUnavailable(
#     587         f"Failed to establish connection to {resolved_address!r} "
#     588         f"(reason {error})"
#     589     ) from error
#     590 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[11], line 5
#       3 password = "ilovemovies"
#       4 conn = Neo4jConnection(uri, user, password)
# ----> 5 conn.reset_database()
#
# Cell In[10], line 11, in Neo4jConnection.reset_database(self)
#       9 def reset_database(self):
#      10     with self.driver.session() as session:
# ---> 11         session.run("MATCH (n) DETACH DELETE n")
#      12         print("Database resetted successfully!")
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_sync/work/session.py:313, in Session.run(self, query, parameters, **kwargs)
#     310     self._auto_result._buffer_all()
#     312 if not self._connection:
# --> 313     self._connect(self._config.default_access_mode)
#     314     assert self._connection is not None
#     315 cx = self._connection
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_sync/work/session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     134     access_mode = self._config.default_access_mode
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#     140     self._handle_cancellation(message="_connect")
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_sync/work/workspace.py:184, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     175 acquire_kwargs_ = {
#     176     "access_mode": access_mode,
#     177     "timeout": acquisition_timeout,
#    (...)
#     181     "liveness_check_timeout": None,
#     182 }
#     183 acquire_kwargs_.update(acquire_kwargs)
# --> 184 self._connection = self._pool.acquire(**acquire_kwargs_)
#     185 self._connection_access_mode = access_mode
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_sync/io/_pool.py:597, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     590 log.debug(
#     591     "[#0000]  _: <POOL> acquire direct connection, "
#     592     "access_mode=%r, database=%r",
#     593     access_mode,
#     594     database,
#     595 )
#     596 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 597 return self._acquire(
#     598     self.address, auth, deadline, liveness_check_timeout
#     599 )
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_sync/io/_pool.py:347, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     342             raise ClientError(
#     343                 "failed to obtain a connection from the pool within "
#     344                 f"{deadline.original_timeout!r}s (timeout)"
#     345             )
#     346 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 347 return connection_creator()
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_sync/io/_pool.py:169, in IOPool._acquire_new_later.<locals>.connection_creator()
#     167 try:
#     168     try:
# --> 169         connection = self.opener(
#     170             address, auth or self.pool_config.auth, deadline
#     171         )
#     172     except ServiceUnavailable:
#     173         self.deactivate(address)
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_sync/io/_pool.py:560, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     559 def opener(addr, auth_manager, deadline):
# --> 560     return Bolt.open(
#     561         addr,
#     562         auth_manager=auth_manager,
#     563         deadline=deadline,
#     564         routing_context=None,
#     565         pool_config=pool_config,
#     566     )
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_sync/io/_bolt.py:448, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     445 if deadline is None:
#     446     deadline = Deadline(None)
# --> 448 s, protocol_version, handshake, data = BoltSocket.connect(
#     449     address,
#     450     tcp_timeout=pool_config.connection_timeout,
#     451     deadline=deadline,
#     452     custom_resolver=pool_config.resolver,
#     453     ssl_context=pool_config.get_ssl_context(),
#     454     keep_alive=pool_config.keep_alive,
#     455 )
#     457 pool_config.protocol_version = protocol_version
#     459 # Carry out Bolt subclass imports locally to avoid circular dependency
#     460 # issues.
#     461
#     462 # avoid new lines after imports for better readability and conciseness
#     463 # fmt: off
#
# File ~/anaconda3/envs/sam/lib/python3.9/site-packages/neo4j/_async_compat/network/_bolt_socket.py:784, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     782 resolved_address_strs = tuple(map(str, resolved_addresses))
#     783 error_strs = "\n".join(map(str, errors))
# --> 784 raise ServiceUnavailable(
#     785     f"Couldn't connect to {address} "
#     786     f"(resolved to {resolved_address_strs}):\n"
#     787     f"{error_strs}"
#     788 ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused)
