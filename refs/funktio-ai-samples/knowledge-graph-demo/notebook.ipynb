# %% [markdown]
# # LLM Powered Consultancy Graph Generation

# %% [markdown]
# ### Outline
# 1. Configuration
# 2. Helper Functions
# 3. Prompts
# 4. Running the pipeline

# %%
# %%capture
# %pip install requirements.txt

# %%
import os
import openai
from string import Template
import json
from neo4j import GraphDatabase
import glob
from timeit import default_timer as timer
from dotenv import load_dotenv
from time import sleep

# %%
print(openai.__version__)
# Out:
# 1.57.2

# %% [markdown]
# ### 1. Configuration

# %%
# Load environment variables
load_dotenv()
# Out:
# True

# %%
# OpenAI API configuration
#openai.api_type = "azure"
openai.api_key = os.getenv("OPENAI_API_KEY")
# openai.api_base = os.getenv("OPENAI_API_BASE")
# openai.api_version = os.getenv("OPENAI_API_VERSION")
openai_deployment = "gpt-4"
openai_deployment = "gpt-3.5-turbo"

# %%
# #-- test 
# from langchain.chat_models import ChatOpenAI

# llm = ChatOpenAI(
#     model = "gpt-4",
#     temperature=0,
#     openai_api_key = openai.api_key
# )

# %%
# Neo4j configuration & constraints
neo4j_url = os.getenv("NEO4J_CONNECTION_URL")
print(neo4j_url)

neo4j_user = os.getenv("NEO4J_USER")
neo4j_password = os.getenv("NEO4J_PASSWORD")
gds = GraphDatabase.driver(neo4j_url, auth=(neo4j_user, neo4j_password))
# Out:
# neo4j+s://6d6cf612.databases.neo4j.io

# %%
completion = openai.chat.completions.create(
    model=openai_deployment,
    max_tokens=2000,
    temperature=0,
    messages=[
        {"role": "system", "content": "You are a helpful IT-project and account management expert who extracts information from documents."},
        {"role": "user", "content": "what is hustory of korea"},
    ],)
nlp_results = completion.choices[0].message.content
print(nlp_results)
# Out:
# It seems like you are asking about the history of Korea. Korea has a long and complex history that dates back thousands of years. Here is a brief overview:
#
# 1. Ancient Korea: The Korean Peninsula has been inhabited for thousands of years. The first Korean kingdom, Gojoseon, was established around 2333 BC. Subsequent kingdoms, such as Goguryeo, Baekje, and Silla, emerged and competed for power on the peninsula.
#
# 2. Unified Silla and Goryeo Dynasty: In 668 AD, the Silla kingdom unified the Korean Peninsula. The Goryeo Dynasty succeeded Silla and ruled from 918 to 1392. During this period, Buddhism flourished, and cultural achievements were made.
#
# 3. Joseon Dynasty: The Joseon Dynasty was founded in 1392 and lasted until 1910. It was a period of Confucian influence, cultural development, and technological advancements. The Korean alphabet, Hangul, was created during this time.
#
# 4. Japanese Occupation: In 1910, Korea was annexed by Japan and remained under Japanese colonial rule until the end of World War II in 1945. This period was marked by oppression and cultural suppression.
#
# 5. Division of Korea: After World War II, Korea was divided into North and South along the 38th parallel. The Korean War (1950-1953) further solidified this division, resulting in the current state of two separate countries, North Korea and South Korea.
#
# 6. Modern Korea: South Korea experienced rapid economic growth and democratization in the latter half of the 20th century, becoming a global economic powerhouse. North Korea, on the other hand, remains isolated and under authoritarian rule.
#
# This is a very simplified overview of the history of Korea. The region has a rich and diverse history with many more details and complexities to explore.

# %% [markdown]
# ### 2. Helper Functions

# %%
# Function to call the OpenAI API
def process_gpt(file_prompt, system_msg):
    completion = openai.chat.completions.create(
        model=openai_deployment,
        max_tokens=2000,
        temperature=0,
        messages=[
            {"role": "system", "content": system_msg},
            {"role": "user", "content": file_prompt},
        ],
    )
    nlp_results = completion.choices[0].message.content
    sleep(8)
    return nlp_results


# Function to take folder of files and a prompt template, and return a json-object of all the entities and relationships
def extract_entities_relationships(folder, prompt_template):
    start = timer()
    files = glob.glob(f"./data/{folder}/*")
    system_msg = "You are a helpful IT-project and account management expert who extracts information from documents."
    print(f"Running pipeline for {len(files)} files in {folder} folder")
    results = []
    for i, file in enumerate(files):
        print(f"Extracting entities and relationships for {file}")
        try:
            with open(file, "r") as f:
                text = f.read().rstrip()
                prompt = Template(prompt_template).substitute(ctext=text)
                #--------------------
                # what is Template? 
                #--------------------
                result = process_gpt(prompt, system_msg=system_msg)
                results.append(json.loads(result))
        except Exception as e:
            print(f"Error processing {file}: {e}")
    end = timer()
    print(f"Pipeline completed in {end-start} seconds")
    
    
    #------ save
    with open(f"/home/eric/srcs/Graph_Lab/sample_data/relation_extraction_result_{folder}.txt", "w",encoding='utf-8') as f:
        f.write(str(results))
    print("#----------------------- save")
    
    return results


# Function to take a json-object of entitites and relationships and generate cypher query for creating those entities
def generate_cypher(json_obj):
    e_statements = []
    r_statements = []

    e_label_map = {}

    # loop through our json object
    for i, obj in enumerate(json_obj):
        print(f"Generating cypher for file {i+1} of {len(json_obj)}")
        for entity in obj["entities"]:
            label = entity["label"]
            id = entity["id"]
            id = id.replace("-", "").replace("_", "")
            properties = {k: v for k, v in entity.items() if k not in ["label", "id"]}

            cypher = f'MERGE (n:{label} {{id: "{id}"}})'
            if properties:
                props_str = ", ".join(
                    [f'n.{key} = "{val}"' for key, val in properties.items()]
                )
                cypher += f" ON CREATE SET {props_str}"
            e_statements.append(cypher)
            e_label_map[id] = label

        for rs in obj["relationships"]:
            src_id, rs_type, tgt_id = rs.split("|")
            src_id = src_id.replace("-", "").replace("_", "")
            tgt_id = tgt_id.replace("-", "").replace("_", "")

            src_label = e_label_map[src_id]
            tgt_label = e_label_map[tgt_id]

            cypher = f'MERGE (a:{src_label} {{id: "{src_id}"}}) MERGE (b:{tgt_label} {{id: "{tgt_id}"}}) MERGE (a)-[:{rs_type}]->(b)'
            r_statements.append(cypher)

    with open("cyphers.txt", "w") as outfile:
        outfile.write("\n".join(e_statements + r_statements))

    return e_statements + r_statements


# Final function to bring all the steps together
def ingestion_pipeline(folders):
    # Extrating the entites and relationships from each folder, append into one json_object
    entities_relationships = []
    for key, value in folders.items():
        entities_relationships.extend(extract_entities_relationships(key, value))


    # Generate and execute cypher statements
    cypher_statements = generate_cypher(entities_relationships)
    for i, stmt in enumerate(cypher_statements):
        print(f"Executing cypher statement {i+1} of {len(cypher_statements)}")
        try:
            gds.execute_query(stmt)
        except Exception as e:
            with open("failed_statements.txt", "w") as f:
                f.write(f"{stmt} - Exception: {e}\n")

# %% [markdown]
# ### 3. Defining Prompts

# %%
# Prompt for processing project briefs
project_prompt_template = """
From the Project Brief below, extract the following Entities & relationships described in the mentioned format 
0. ALWAYS FINISH THE OUTPUT. Never send partial responses
1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
   `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. Document must be summarized and stored inside Project entity under `summary` property. You will have to generate as many entities as needed as per the types below:
    Entity Types:
    label:'Project',id:string,name:string;summary:string //Project mentioned in the brief; `id` property is the full name of the project, in lowercase, with no capital letters, special characters, spaces or hyphens; Contents of original document must be summarized inside 'summary' property
    label:'Technology',id:string,name:string //Technology Entity; `id` property is the name of the technology, in camel-case. Identify as many of the technologies used as possible
    label:'Client',id:string,name:string;industry:string //Client that the project was done for; `id` property is the name of the Client, in camel-case; 'industry' is the industry that the client operates in, as mentioned in the project brief.
    
2. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
    Relationship types:
    project|USES_TECH|technology 
    project|HAS_CLIENT|client


3. The output should look like :
{
    "entities": [{"label":"Project","id":string,"name":string,"summary":string}],
    "relationships": ["projectid|USES_TECH|technologyid"]
}

Case Sheet:
$ctext
"""


# Prompt for processing peoples' profiles
people_prompt_template = """From the list of people below, extract the following Entities & relationships described in the mentioned format 
0. ALWAYS FINISH THE OUTPUT. Never send partial responses
1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
   `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. You will have to generate as many entities as needed as per the types below:
    Entity Types:
    label:'Person',id:string,name:string //Person that the data is about. `id` property is the name of the person, in camel-case. 'name' is the person's name, as spelled in the text.
    label:'Project',id:string,name:string;summary:string //Project mentioned in the profile; `id` property is the full lowercase name of the project, with no capital letters, special characters, spaces or hyphens.
    label:'Technology',id:string,name:string //Technology Entity, as listed in the "skills"-section of every person; `id` property is the name of the technology, in camel-case.
    
3. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
    Relationship types:
    person|HAS_SKILLS|technology 
    project|HAS_PEOPLE|person


The output should look like :
{
    "entities": [{"label":"Person","id":string,"name":string}],
    "relationships": ["projectid|HAS_PEOPLE|personid"]
}

Case Sheet:
$ctext
"""


# Prompt for processing slack messages

slack_prompt_template = """
From the list of messages below, extract the following Entities & relationships described in the mentioned format 
0. ALWAYS FINISH THE OUTPUT. Never send partial responses
1. First, look for these Entity types in the text and generate as comma-separated format similar to entity type.
   `id` property of each entity must be alphanumeric and must be unique among the entities. You will be referring this property to define the relationship between entities. Do not create new entity types that aren't mentioned below. You will have to generate as many entities as needed as per the types below:
    Entity Types:
    label:'Person',id:string,name:string //Person that sent the message. `id` property is the name of the person, in camel-case; for example, "michaelClark", or "emmaMartinez"; 'name' is the person's name, as spelled in the text.
    label:'SlackMessage',id:string,text:string //The Slack-Message that was sent; 'id' property should be the message id, as spelled in the reference. 'text' property is the text content of the message, as spelled in the reference
    
3. Next generate each relationships as triples of head, relationship and tail. To refer the head and tail entity, use their respective `id` property. Relationship property should be mentioned within brackets as comma-separated. They should follow these relationship types below. You will have to generate as many relationships as needed as defined below:
    Relationship types:
    personid|SENT|slackmessageid

The output should look like :
{
    "entities": [{"label":"SlackMessage","id":string,"text":string}],
    "relationships": ["personid|SENT|messageid"]
}

Case Sheet:
$ctext
"""

# %% [markdown]
# ### 4. Running the pipeline

# %%
folders = {
    "people_profiles": people_prompt_template,
    "project_briefs": project_prompt_template,
    "slack_messages": slack_prompt_template,
}

ingestion_pipeline(folders)
# Out:
# Running pipeline for 3 files in people_profiles folder
# Extracting entities and relationships for ./data/people_profiles/people-profiles3.md
# Extracting entities and relationships for ./data/people_profiles/people-profiles1.md
# Extracting entities and relationships for ./data/people_profiles/people-profiles2.md
# Pipeline completed in 55.64424351043999 seconds
# #----------------------- save
# Running pipeline for 11 files in project_briefs folder
# Extracting entities and relationships for ./data/project_briefs/GammaTech Autonomous Fleet Management System on Azure.md
# Extracting entities and relationships for ./data/project_briefs/EpsilonFinance Mobile-First Digital Wallet on Google Cloud.md
# Extracting entities and relationships for ./data/project_briefs/DeltaEdu Virtual Classroom Platform on AWS.md
# Extracting entities and relationships for ./data/project_briefs/BetaHealth AI-Driven Patient Care Enhancement Platform on Azure.md
# Extracting entities and relationships for ./data/project_briefs/GammaTech Smart Logistics Platform on Azure.md
# Extracting entities and relationships for ./data/project_briefs/AlphaCorp Customer Support Chatbot.md
# Extracting entities and relationships for ./data/project_briefs/BetaHealth Secure Healthcare Data Analytics Platform on Azure.md
# Extracting entities and relationships for ./data/project_briefs/BetaHealth Telemedicine Platform on Microsoft Azure.md
# Extracting entities and relationships for ./data/project_briefs/AlphaCorp AWS-Powered Sales Analytics Dashboard.md
# Extracting entities and relationships for ./data/project_briefs/AlphaCorp Supply Chain Optimization Platform.md
# Extracting entities and relationships for ./data/project_briefs/DeltaEdu AI-Powered Student Performance Analytics on AWS.md
# Pipeline completed in 138.6822892408818 seconds
# #----------------------- save
# Running pipeline for 7 files in slack_messages folder
# Extracting entities and relationships for ./data/slack_messages/slack_messages5.json
# Extracting entities and relationships for ./data/slack_messages/slack_messages4.json
# Extracting entities and relationships for ./data/slack_messages/slack_messages7.json
# Extracting entities and relationships for ./data/slack_messages/slack_messages2.json
# Extracting entities and relationships for ./data/slack_messages/slack_messages1.json
# Extracting entities and relationships for ./data/slack_messages/slack_messages3.json
# Extracting entities and relationships for ./data/slack_messages/slack_messages6.json
# Pipeline completed in 84.68298313952982 seconds
# #----------------------- save
# Generating cypher for file 1 of 21
# Generating cypher for file 2 of 21
# Generating cypher for file 3 of 21
# Generating cypher for file 4 of 21
# Generating cypher for file 5 of 21
# Generating cypher for file 6 of 21
# Generating cypher for file 7 of 21
# Generating cypher for file 8 of 21
# Generating cypher for file 9 of 21
# Generating cypher for file 10 of 21
# Generating cypher for file 11 of 21
# Generating cypher for file 12 of 21
# Generating cypher for file 13 of 21
# Generating cypher for file 14 of 21
# Generating cypher for file 15 of 21
# Generating cypher for file 16 of 21
# Generating cypher for file 17 of 21
# Generating cypher for file 18 of 21
# Generating cypher for file 19 of 21
# Generating cypher for file 20 of 21
# Generating cypher for file 21 of 21
# Executing cypher statement 1 of 438
# Executing cypher statement 2 of 438
# Executing cypher statement 3 of 438
# Executing cypher statement 4 of 438
# Executing cypher statement 5 of 438
# Executing cypher statement 6 of 438
# Executing cypher statement 7 of 438
# Executing cypher statement 8 of 438
# Executing cypher statement 9 of 438
# Executing cypher statement 10 of 438
# Executing cypher statement 11 of 438
# Executing cypher statement 12 of 438
# Executing cypher statement 13 of 438
# Executing cypher statement 14 of 438
# Executing cypher statement 15 of 438
# Executing cypher statement 16 of 438
# Executing cypher statement 17 of 438
# Executing cypher statement 18 of 438
# Executing cypher statement 19 of 438
# Executing cypher statement 20 of 438
# Executing cypher statement 21 of 438
# Executing cypher statement 22 of 438
# Executing cypher statement 23 of 438
# Executing cypher statement 24 of 438
# Executing cypher statement 25 of 438
# Executing cypher statement 26 of 438
# Executing cypher statement 27 of 438
# Executing cypher statement 28 of 438
# Executing cypher statement 29 of 438
# Executing cypher statement 30 of 438
# Executing cypher statement 31 of 438
# Executing cypher statement 32 of 438
# Executing cypher statement 33 of 438
# Executing cypher statement 34 of 438
# Executing cypher statement 35 of 438
# Executing cypher statement 36 of 438
# Executing cypher statement 37 of 438
# Executing cypher statement 38 of 438
# Executing cypher statement 39 of 438
# Executing cypher statement 40 of 438
# Executing cypher statement 41 of 438
# Executing cypher statement 42 of 438
# Executing cypher statement 43 of 438
# Executing cypher statement 44 of 438
# Executing cypher statement 45 of 438
# Executing cypher statement 46 of 438
# Executing cypher statement 47 of 438
# Executing cypher statement 48 of 438
# Executing cypher statement 49 of 438
# Executing cypher statement 50 of 438
# Executing cypher statement 51 of 438
# Executing cypher statement 52 of 438
# Executing cypher statement 53 of 438
# Executing cypher statement 54 of 438
# Executing cypher statement 55 of 438
# Executing cypher statement 56 of 438
# Executing cypher statement 57 of 438
# Executing cypher statement 58 of 438
# Executing cypher statement 59 of 438
# Executing cypher statement 60 of 438
# Executing cypher statement 61 of 438
# Executing cypher statement 62 of 438
# Executing cypher statement 63 of 438
# Executing cypher statement 64 of 438
# Executing cypher statement 65 of 438
# Executing cypher statement 66 of 438
# Executing cypher statement 67 of 438
# Executing cypher statement 68 of 438
# Executing cypher statement 69 of 438
# Executing cypher statement 70 of 438
# Executing cypher statement 71 of 438
# Executing cypher statement 72 of 438
# Executing cypher statement 73 of 438
# Executing cypher statement 74 of 438
# Executing cypher statement 75 of 438
# Executing cypher statement 76 of 438
# Executing cypher statement 77 of 438
# Executing cypher statement 78 of 438
# Executing cypher statement 79 of 438
# Executing cypher statement 80 of 438
# Executing cypher statement 81 of 438
# Executing cypher statement 82 of 438
# Executing cypher statement 83 of 438
# Executing cypher statement 84 of 438
# Executing cypher statement 85 of 438
# Executing cypher statement 86 of 438
# Executing cypher statement 87 of 438
# Executing cypher statement 88 of 438
# Executing cypher statement 89 of 438
# Executing cypher statement 90 of 438
# Executing cypher statement 91 of 438
# Executing cypher statement 92 of 438
# Executing cypher statement 93 of 438
# Executing cypher statement 94 of 438
# Executing cypher statement 95 of 438
# Executing cypher statement 96 of 438
# Executing cypher statement 97 of 438
# Executing cypher statement 98 of 438
# Executing cypher statement 99 of 438
# Executing cypher statement 100 of 438
# Executing cypher statement 101 of 438
# Executing cypher statement 102 of 438
# Executing cypher statement 103 of 438
# Executing cypher statement 104 of 438
# Executing cypher statement 105 of 438
# Executing cypher statement 106 of 438
# Executing cypher statement 107 of 438
# Executing cypher statement 108 of 438
# Executing cypher statement 109 of 438
# Executing cypher statement 110 of 438
# Executing cypher statement 111 of 438
# Executing cypher statement 112 of 438
# Executing cypher statement 113 of 438
# Executing cypher statement 114 of 438
# Executing cypher statement 115 of 438
# Executing cypher statement 116 of 438
# Executing cypher statement 117 of 438
# Executing cypher statement 118 of 438
# Executing cypher statement 119 of 438
# Executing cypher statement 120 of 438
# Executing cypher statement 121 of 438
# Executing cypher statement 122 of 438
# Executing cypher statement 123 of 438
# Executing cypher statement 124 of 438
# Executing cypher statement 125 of 438
# Executing cypher statement 126 of 438
# Executing cypher statement 127 of 438
# Executing cypher statement 128 of 438
# Executing cypher statement 129 of 438
# Executing cypher statement 130 of 438
# Executing cypher statement 131 of 438
# Executing cypher statement 132 of 438
# Executing cypher statement 133 of 438
# Executing cypher statement 134 of 438
# Executing cypher statement 135 of 438
# Executing cypher statement 136 of 438
# Executing cypher statement 137 of 438
# Executing cypher statement 138 of 438
# Executing cypher statement 139 of 438
# Executing cypher statement 140 of 438
# Executing cypher statement 141 of 438
# Executing cypher statement 142 of 438
# Executing cypher statement 143 of 438
# Executing cypher statement 144 of 438
# Executing cypher statement 145 of 438
# Executing cypher statement 146 of 438
# Executing cypher statement 147 of 438
# Executing cypher statement 148 of 438
# Executing cypher statement 149 of 438
# Executing cypher statement 150 of 438
# Executing cypher statement 151 of 438
# Executing cypher statement 152 of 438
# Executing cypher statement 153 of 438
# Executing cypher statement 154 of 438
# Executing cypher statement 155 of 438
# Executing cypher statement 156 of 438
# Executing cypher statement 157 of 438
# Executing cypher statement 158 of 438
# Executing cypher statement 159 of 438
# Executing cypher statement 160 of 438
# Executing cypher statement 161 of 438
# Executing cypher statement 162 of 438
# Executing cypher statement 163 of 438
# Executing cypher statement 164 of 438
# Executing cypher statement 165 of 438
# Executing cypher statement 166 of 438
# Executing cypher statement 167 of 438
# Executing cypher statement 168 of 438
# Executing cypher statement 169 of 438
# Executing cypher statement 170 of 438
# Executing cypher statement 171 of 438
# Executing cypher statement 172 of 438
# Executing cypher statement 173 of 438
# Executing cypher statement 174 of 438
# Executing cypher statement 175 of 438
# Executing cypher statement 176 of 438
# Executing cypher statement 177 of 438
# Executing cypher statement 178 of 438
# Executing cypher statement 179 of 438
# Executing cypher statement 180 of 438
# Executing cypher statement 181 of 438
# Executing cypher statement 182 of 438
# Executing cypher statement 183 of 438
# Executing cypher statement 184 of 438
# Executing cypher statement 185 of 438
# Executing cypher statement 186 of 438
# Executing cypher statement 187 of 438
# Executing cypher statement 188 of 438
# Executing cypher statement 189 of 438
# Executing cypher statement 190 of 438
# Executing cypher statement 191 of 438
# Executing cypher statement 192 of 438
# Executing cypher statement 193 of 438
# Executing cypher statement 194 of 438
# Executing cypher statement 195 of 438
# Executing cypher statement 196 of 438
# Executing cypher statement 197 of 438
# Executing cypher statement 198 of 438
# Executing cypher statement 199 of 438
# Executing cypher statement 200 of 438
# Executing cypher statement 201 of 438
# Executing cypher statement 202 of 438
# Executing cypher statement 203 of 438
# Executing cypher statement 204 of 438
# Executing cypher statement 205 of 438
# Executing cypher statement 206 of 438
# Executing cypher statement 207 of 438
# Executing cypher statement 208 of 438
# Executing cypher statement 209 of 438
# Executing cypher statement 210 of 438
# Executing cypher statement 211 of 438
# Executing cypher statement 212 of 438
# Executing cypher statement 213 of 438
# Executing cypher statement 214 of 438
# Executing cypher statement 215 of 438
# Executing cypher statement 216 of 438
# Executing cypher statement 217 of 438
# Executing cypher statement 218 of 438
# Executing cypher statement 219 of 438
# Executing cypher statement 220 of 438
# Executing cypher statement 221 of 438
# Executing cypher statement 222 of 438
# Executing cypher statement 223 of 438
# Executing cypher statement 224 of 438
# Executing cypher statement 225 of 438
# Executing cypher statement 226 of 438
# Executing cypher statement 227 of 438
# Executing cypher statement 228 of 438
# Executing cypher statement 229 of 438
# Executing cypher statement 230 of 438
# Executing cypher statement 231 of 438
# Executing cypher statement 232 of 438
# Executing cypher statement 233 of 438
# Executing cypher statement 234 of 438
# Executing cypher statement 235 of 438
# Executing cypher statement 236 of 438
# Executing cypher statement 237 of 438
# Executing cypher statement 238 of 438
# Executing cypher statement 239 of 438
# Executing cypher statement 240 of 438
# Executing cypher statement 241 of 438
# Executing cypher statement 242 of 438
# Executing cypher statement 243 of 438
# Executing cypher statement 244 of 438
# Executing cypher statement 245 of 438
# Executing cypher statement 246 of 438
# Executing cypher statement 247 of 438
# Executing cypher statement 248 of 438
# Executing cypher statement 249 of 438
# Executing cypher statement 250 of 438
# Executing cypher statement 251 of 438
# Executing cypher statement 252 of 438
# Executing cypher statement 253 of 438
# Executing cypher statement 254 of 438
# Executing cypher statement 255 of 438
# Executing cypher statement 256 of 438
# Executing cypher statement 257 of 438
# Executing cypher statement 258 of 438
# Executing cypher statement 259 of 438
# Executing cypher statement 260 of 438
# Executing cypher statement 261 of 438
# Executing cypher statement 262 of 438
# Executing cypher statement 263 of 438
# Executing cypher statement 264 of 438
# Executing cypher statement 265 of 438
# Executing cypher statement 266 of 438
# Executing cypher statement 267 of 438
# Executing cypher statement 268 of 438
# Executing cypher statement 269 of 438
# Executing cypher statement 270 of 438
# Executing cypher statement 271 of 438
# Executing cypher statement 272 of 438
# Executing cypher statement 273 of 438
# Executing cypher statement 274 of 438
# Executing cypher statement 275 of 438
# Executing cypher statement 276 of 438
# Executing cypher statement 277 of 438
# Executing cypher statement 278 of 438
# Executing cypher statement 279 of 438
# Executing cypher statement 280 of 438
# Executing cypher statement 281 of 438
# Executing cypher statement 282 of 438
# Executing cypher statement 283 of 438
# Executing cypher statement 284 of 438
# Executing cypher statement 285 of 438
# Executing cypher statement 286 of 438
# Executing cypher statement 287 of 438
# Executing cypher statement 288 of 438
# Executing cypher statement 289 of 438
# Executing cypher statement 290 of 438
# Executing cypher statement 291 of 438
# Executing cypher statement 292 of 438
# Executing cypher statement 293 of 438
# Executing cypher statement 294 of 438
# Executing cypher statement 295 of 438
# Executing cypher statement 296 of 438
# Executing cypher statement 297 of 438
# Executing cypher statement 298 of 438
# Executing cypher statement 299 of 438
# Executing cypher statement 300 of 438
# Executing cypher statement 301 of 438
# Executing cypher statement 302 of 438
# Executing cypher statement 303 of 438
# Executing cypher statement 304 of 438
# Executing cypher statement 305 of 438
# Executing cypher statement 306 of 438
# Executing cypher statement 307 of 438
# Executing cypher statement 308 of 438
# Executing cypher statement 309 of 438
# Executing cypher statement 310 of 438
# Executing cypher statement 311 of 438
# Executing cypher statement 312 of 438
# Executing cypher statement 313 of 438
# Executing cypher statement 314 of 438
# Executing cypher statement 315 of 438
# Executing cypher statement 316 of 438
# Executing cypher statement 317 of 438
# Executing cypher statement 318 of 438
# Executing cypher statement 319 of 438
# Executing cypher statement 320 of 438
# Executing cypher statement 321 of 438
# Executing cypher statement 322 of 438
# Executing cypher statement 323 of 438
# Executing cypher statement 324 of 438
# Executing cypher statement 325 of 438
# Executing cypher statement 326 of 438
# Executing cypher statement 327 of 438
# Executing cypher statement 328 of 438
# Executing cypher statement 329 of 438
# Executing cypher statement 330 of 438
# Executing cypher statement 331 of 438
# Executing cypher statement 332 of 438
# Executing cypher statement 333 of 438
# Executing cypher statement 334 of 438
# Executing cypher statement 335 of 438
# Executing cypher statement 336 of 438
# Executing cypher statement 337 of 438
# Executing cypher statement 338 of 438
# Executing cypher statement 339 of 438
# Executing cypher statement 340 of 438
# Executing cypher statement 341 of 438
# Executing cypher statement 342 of 438
# Executing cypher statement 343 of 438
# Executing cypher statement 344 of 438
# Executing cypher statement 345 of 438
# Executing cypher statement 346 of 438
# Executing cypher statement 347 of 438
# Executing cypher statement 348 of 438
# Executing cypher statement 349 of 438
# Executing cypher statement 350 of 438
# Executing cypher statement 351 of 438
# Executing cypher statement 352 of 438
# Executing cypher statement 353 of 438
# Executing cypher statement 354 of 438
# Executing cypher statement 355 of 438
# Executing cypher statement 356 of 438
# Executing cypher statement 357 of 438
# Executing cypher statement 358 of 438
# Executing cypher statement 359 of 438
# Executing cypher statement 360 of 438
# Executing cypher statement 361 of 438
# Executing cypher statement 362 of 438
# Executing cypher statement 363 of 438
# Executing cypher statement 364 of 438
# Executing cypher statement 365 of 438
# Executing cypher statement 366 of 438
# Executing cypher statement 367 of 438
# Executing cypher statement 368 of 438
# Executing cypher statement 369 of 438
# Executing cypher statement 370 of 438
# Executing cypher statement 371 of 438
# Executing cypher statement 372 of 438
# Executing cypher statement 373 of 438
# Executing cypher statement 374 of 438
# Executing cypher statement 375 of 438
# Executing cypher statement 376 of 438
# Executing cypher statement 377 of 438
# Executing cypher statement 378 of 438
# Executing cypher statement 379 of 438
# Executing cypher statement 380 of 438
# Executing cypher statement 381 of 438
# Executing cypher statement 382 of 438
# Executing cypher statement 383 of 438
# Executing cypher statement 384 of 438
# Executing cypher statement 385 of 438
# Executing cypher statement 386 of 438
# Executing cypher statement 387 of 438
# Executing cypher statement 388 of 438
# Executing cypher statement 389 of 438
# Executing cypher statement 390 of 438
# Executing cypher statement 391 of 438
# Executing cypher statement 392 of 438
# Executing cypher statement 393 of 438
# Executing cypher statement 394 of 438
# Executing cypher statement 395 of 438
# Executing cypher statement 396 of 438
# Executing cypher statement 397 of 438
# Executing cypher statement 398 of 438
# Executing cypher statement 399 of 438
# Executing cypher statement 400 of 438
# Executing cypher statement 401 of 438
# Executing cypher statement 402 of 438
# Executing cypher statement 403 of 438
# Executing cypher statement 404 of 438
# Executing cypher statement 405 of 438
# Executing cypher statement 406 of 438
# Executing cypher statement 407 of 438
# Executing cypher statement 408 of 438
# Executing cypher statement 409 of 438
# Executing cypher statement 410 of 438
# Executing cypher statement 411 of 438
# Executing cypher statement 412 of 438
# Executing cypher statement 413 of 438
# Executing cypher statement 414 of 438
# Executing cypher statement 415 of 438
# Executing cypher statement 416 of 438
# Executing cypher statement 417 of 438
# Executing cypher statement 418 of 438
# Executing cypher statement 419 of 438
# Executing cypher statement 420 of 438
# Executing cypher statement 421 of 438
# Executing cypher statement 422 of 438
# Executing cypher statement 423 of 438
# Executing cypher statement 424 of 438
# Executing cypher statement 425 of 438
# Executing cypher statement 426 of 438
# Executing cypher statement 427 of 438
# Executing cypher statement 428 of 438
# Executing cypher statement 429 of 438
# Executing cypher statement 430 of 438
# Executing cypher statement 431 of 438
# Executing cypher statement 432 of 438
# Executing cypher statement 433 of 438
# Executing cypher statement 434 of 438
# Executing cypher statement 435 of 438
# Executing cypher statement 436 of 438
# Executing cypher statement 437 of 438
# Executing cypher statement 438 of 438
